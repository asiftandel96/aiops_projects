# %%
# Importing the os library
import os

# %%
# Checking the current directory in the notebook
print(os.getcwd())
# Out:
# D:\MLOPS Projects\aiops_projects\notebook

# %%
# Checking the list of files in parent directory
os.listdir(os.pardir)
# Out:
# ['.git',
#  '.gitignore',
#  '.idea',
#  'CodeNotes.txt',
#  'data',
#  'main.py',
#  'notebook',
#  'README.md',
#  'requirements.txt',
#  'venv']

# %%
# Changing the current directory path

print(f"Current Directory:{os.getcwd()}")
os.chdir(os.pardir)
print(f"Current Directory:{os.getcwd()}")
# Out:
# Current Directory:D:\MLOPS Projects\aiops_projects\notebook
# Current Directory:D:\MLOPS Projects\aiops_projects

# %%
# "Good Pratice"
from pathlib import Path
workdir=str(Path("D:/MLOPS Projects/aiops_projects"))

# %%
print(type(workdir))
# Out:
# <class 'str'>

# %%
#Configuration File

class Config:
    
    def __init__(self):
        self.work_dir=workdir
        self.data_dir=os.path.join(workdir,"data")
        self.csv_file_name="house_prices.csv"
        self.csv_file_path=os.path.join(self.data_dir,self.csv_file_name)
        self.pipeline_name="aiops_pipeline"
        self.pipeline_root=os.path.join("aiops_pipeline_artifact")
        self.meta_data_path=os.path.join("aiops_pipeline_metadata",self.pipeline_name,"metadata.db")

# %%
config=Config()

# %%
config.work_dir
# Out:
# 'D:\\MLOPS Projects\\aiops_projects'

# %%
from tfx.orchestration.metadata import sqlite_metadata_connection_config

# %%
from tfx.orchestration.experimental.interactive.interactive_context import InteractiveContext

# %%
interactive_context=InteractiveContext(
    pipeline_name=config.pipeline_name,
    pipeline_root=config.pipeline_root,
    metadata_connection_config=sqlite_metadata_connection_config(config.meta_data_path))

# %%
from tfx.components import CsvExampleGen

# %%
csv_example_gen=CsvExampleGen(input_base=config.data_dir)

# %%
interactive_context.run(csv_example_gen)
# Out:
# WARNING:root:Make sure that locally built Python SDK docker image has Python 3.7 interpreter.
# WARNING:apache_beam.io.tfrecordio:Couldn't find python-snappy so the implementation of _TFRecordUtil._masked_crc32c is not as fast as it could be.
# ExecutionResult(
#     component_id: CsvExampleGen
#     execution_id: 2
#     outputs:
#         examples: Channel(
#             type_name: Examples
#             artifacts: [Artifact(artifact: id: 2
#         type_id: 14
#         uri: "aiops_pipeline_artifact\\CsvExampleGen\\examples\\2"
#         properties {
#           key: "split_names"
#           value {
#             string_value: "[\"train\", \"eval\"]"
#           }
#         }
#         custom_properties {
#           key: "file_format"
#           value {
#             string_value: "tfrecords_gzip"
#           }
#         }
#         custom_properties {
#           key: "input_fingerprint"
#           value {
#             string_value: "split:single_split,num_files:1,total_bytes:16317,xor_checksum:1617533382,sum_checksum:1617533382"
#           }
#         }
#         custom_properties {
#           key: "payload_format"
#           value {
#             string_value: "FORMAT_TF_EXAMPLE"
#           }
#         }
#         custom_properties {
#           key: "span"
#           value {
#             int_value: 0
#           }
#         }
#         custom_properties {
#           key: "state"
#           value {
#             string_value: "published"
#           }
#         }
#         custom_properties {
#           key: "tfx_version"
#           value {
#             string_value: "1.6.1"
#           }
#         }
#         state: LIVE
#         , artifact_type: id: 14
#         name: "Examples"
#         properties {
#           key: "span"
#           value: INT
#         }
#         properties {
#           key: "split_names"
#           value: STRING
#         }
#         properties {
#           key: "version"
#           value: INT
#         }
#         base_type: DATASET
#         )]
#             additional_properties: {}
#             additional_custom_properties: {}
#         ))
